# %% [markdown]
# <a href="https://colab.research.google.com/github/Estefany66/Ciencia-de-Datos/blob/main/AnalisisdeDatosSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerías utilizadas

import os
import glob
from pathlib import Path

import pandas as pd

# %%
BASE_DIR = Path.cwd()
BASE_DIR
# Out:
# PosixPath('/content')

# %%
# Lectura de los archivos y creación de un DF con todos los datos

def read_files(FILES, col, long):

    df = pd.DataFrame()

    for filename in glob.glob(f"{BASE_DIR / FILES}"):
        df_aux = pd.read_excel(filename)

        info_file = Path(filename).name[:long]
        df_aux[col] = info_file

        df = pd.concat([df, df_aux])

    return df

# %%
FILES_NE_HIST = '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Ventas_SF.xlsx'
FILES_NE_HIST
# Out:
# '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Ventas_SF.xlsx'

# %%
[Path(filename).name for filename in glob.glob(f"{BASE_DIR / FILES_NE_HIST}")]
# Out:
# ['Ventas_SF.xlsx']

# %%
# %%time

df_ne_hist = read_files(FILES_NE_HIST, 'tipo', 2)

df_ne_hist
# Out:
# CPU times: user 1.29 s, sys: 33.8 ms, total: 1.32 s
# Wall time: 1.91 s
#                    Número                 Cliente  Nº Control       Venc.  \
# 0     PC: 00001-000015661       CLIENTE EVENTUAL     10005945  19/01/2022
# 1     PC: 00001-000015646       CLIENTE EVENTUAL     10005945  14/01/2022
# 2     PC: 00001-000015643       CLIENTE EVENTUAL     10005945  14/01/2022
# 3     PC: 00001-000015871       CLIENTE EVENTUAL     10005945  14/03/2022
# 4     PC: 00001-000015838       CLIENTE EVENTUAL     10005945   4/03/2022
# ...                   ...                     ...         ...         ...
# 5331   PC 00005-000051634     PIERO CHALCO MONTES       51634  22/08/2023
# 5332   PC 00005-000051635  EDUARDO ARANA VIZCARRA       51635  23/08/2023
# 5333   PC 00005-000051635  EDUARDO ARANA VIZCARRA       51635  23/08/2023
# 5334   PC 00005-000051636   RICHARD VIZCARRA MEZA       51636  23/08/2023
# 5335   PC 00005-000051636   RICHARD VIZCARRA MEZA       51636  23/08/2023
#
# ...

# %%
df_ne_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5336 entries, 0 to 5335
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Número      5336 non-null   object
#  1   Cliente     5336 non-null   object
#  2   Nº Control  5336 non-null   int64
#  3   Venc.       5336 non-null   object
#  4    Neto       5336 non-null   float64
#  5   tipo        5336 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 250.2+ KB

# %%
# Buscamos las filas con valores NaN
# Corresponden a los encabezados de las ventas del día
# y los totales
df_ne_hist[ df_ne_hist.isnull().values ]
# Out:
# Empty DataFrame
# Columns: [Número, Cliente, Nº Control, Venc.,  Neto, tipo]
# Index: []

# %%
# Eliminamos los registros que contienen NaN ya que corresponden a
df_ne_hist.dropna(inplace=True)
df_ne_hist
# Out:
#                    Número                 Cliente  Nº Control       Venc.  \
# 0     PC: 00001-000015661       CLIENTE EVENTUAL     10005945  19/01/2022
# 1     PC: 00001-000015646       CLIENTE EVENTUAL     10005945  14/01/2022
# 2     PC: 00001-000015643       CLIENTE EVENTUAL     10005945  14/01/2022
# 3     PC: 00001-000015871       CLIENTE EVENTUAL     10005945  14/03/2022
# 4     PC: 00001-000015838       CLIENTE EVENTUAL     10005945   4/03/2022
# ...                   ...                     ...         ...         ...
# 5331   PC 00005-000051634     PIERO CHALCO MONTES       51634  22/08/2023
# 5332   PC 00005-000051635  EDUARDO ARANA VIZCARRA       51635  23/08/2023
# 5333   PC 00005-000051635  EDUARDO ARANA VIZCARRA       51635  23/08/2023
# 5334   PC 00005-000051636   RICHARD VIZCARRA MEZA       51636  23/08/2023
# 5335   PC 00005-000051636   RICHARD VIZCARRA MEZA       51636  23/08/2023
#
#        Neto tipo
# 0      10.0   Ve
# 1      10.0   Ve
# 2      10.0   Ve
# ...

# %%
# Cambio del nombre de las columnas
df_ne_hist.columns
# Out:
# Index(['Número', 'Cliente', 'Nº Control', 'Venc.', ' Neto', 'tipo'], dtype='object')

# %%
cols = ['num',
        'cliente',
        'control',
        'fecha_comp',
        'monto',
        'tipo']

# %%
df_ne_hist.columns = cols
df_ne_hist
# Out:
#                       num                 cliente   control  fecha_comp  \
# 0     PC: 00001-000015661       CLIENTE EVENTUAL   10005945  19/01/2022
# 1     PC: 00001-000015646       CLIENTE EVENTUAL   10005945  14/01/2022
# 2     PC: 00001-000015643       CLIENTE EVENTUAL   10005945  14/01/2022
# 3     PC: 00001-000015871       CLIENTE EVENTUAL   10005945  14/03/2022
# 4     PC: 00001-000015838       CLIENTE EVENTUAL   10005945   4/03/2022
# ...                   ...                     ...       ...         ...
# 5331   PC 00005-000051634     PIERO CHALCO MONTES     51634  22/08/2023
# 5332   PC 00005-000051635  EDUARDO ARANA VIZCARRA     51635  23/08/2023
# 5333   PC 00005-000051635  EDUARDO ARANA VIZCARRA     51635  23/08/2023
# 5334   PC 00005-000051636   RICHARD VIZCARRA MEZA     51636  23/08/2023
# 5335   PC 00005-000051636   RICHARD VIZCARRA MEZA     51636  23/08/2023
#
#       monto tipo
# 0      10.0   Ve
# 1      10.0   Ve
# 2      10.0   Ve
# 3      20.0   Ve
# ...

# %%
df_ne_hist = df_ne_hist.loc[:,['num', 'fecha_comp', 'cliente', 'monto', 'tipo']]
df_ne_hist
# Out:
#                       num  fecha_comp                 cliente  monto tipo
# 0     PC: 00001-000015661  19/01/2022       CLIENTE EVENTUAL    10.0   Ve
# 1     PC: 00001-000015646  14/01/2022       CLIENTE EVENTUAL    10.0   Ve
# 2     PC: 00001-000015643  14/01/2022       CLIENTE EVENTUAL    10.0   Ve
# 3     PC: 00001-000015871  14/03/2022       CLIENTE EVENTUAL    20.0   Ve
# 4     PC: 00001-000015838   4/03/2022       CLIENTE EVENTUAL    10.0   Ve
# ...                   ...         ...                     ...    ...  ...
# 5331   PC 00005-000051634  22/08/2023     PIERO CHALCO MONTES  475.0   Ve
# 5332   PC 00005-000051635  23/08/2023  EDUARDO ARANA VIZCARRA  110.0   Ve
# 5333   PC 00005-000051635  23/08/2023  EDUARDO ARANA VIZCARRA  120.0   Ve
# 5334   PC 00005-000051636  23/08/2023   RICHARD VIZCARRA MEZA    0.0   Ve
# 5335   PC 00005-000051636  23/08/2023   RICHARD VIZCARRA MEZA   90.0   Ve
#
# [5336 rows x 5 columns]

# %%
df_ne_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5336 entries, 0 to 5335
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num         5336 non-null   object
#  1   fecha_comp  5336 non-null   object
#  2   cliente     5336 non-null   object
#  3   monto       5336 non-null   float64
#  4   tipo        5336 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 208.6+ KB

# %% [markdown]
# Archivo hitórico FA

# %%
FILES_FA_HIST = '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Ventas_SF_fa.xlsx'
FILES_FA_HIST
# Out:
# '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Ventas_SF_fa.xlsx'

# %%
[Path(filename).name for filename in glob.glob(f"{BASE_DIR / FILES_FA_HIST}")]
# Out:
# ['Ventas_SF_fa.xlsx']

# %%
# %%time

df_fa_hist = read_files(FILES_FA_HIST, 'tipo', 2)

df_fa_hist
# Out:
# CPU times: user 777 ms, sys: 6.32 ms, total: 783 ms
# Wall time: 1.46 s
#                    Número    Emisión                 Venc.  \
# 0     PC: 00001-000015661  19/01/2022           19/01/2022
# 1     PC: 00001-000015646  14/01/2022           14/01/2022
# 2     PC: 00001-000015643  14/01/2022           14/01/2022
# 3     PC: 00001-000015871  14/03/2022           14/03/2022
# 4     PC: 00001-000015838   4/03/2022            4/03/2022
# ...                   ...         ...                  ...
# 5331   PC 00005-000051634  22/08/2023  22/08/2023 20:09:34
# 5332   PC 00005-000051635  23/08/2023  23/08/2023 10:12:20
# 5333   PC 00005-000051635  23/08/2023  23/08/2023 10:12:20
# 5334   PC 00005-000051636  23/08/2023  23/08/2023 10:32:42
# 5335   PC 00005-000051636  23/08/2023  23/08/2023 10:32:42
#
#                      Cliente  Monto Base   I.G.V  Otros   Neto  Saldo tipo
# 0          CLIENTE EVENTUAL         8.47   1.525      0   10.0    0.0   Ve
# ...

# %%
df_fa_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5336 entries, 0 to 5335
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Número      5336 non-null   object
#  1   Emisión     5336 non-null   object
#  2   Venc.       5336 non-null   object
#  3   Cliente     5336 non-null   object
#  4   Monto Base  5336 non-null   float64
#  5   I.G.V       5336 non-null   float64
#  6   Otros       5336 non-null   int64
#  7   Neto        5336 non-null   float64
#  8   Saldo       4571 non-null   float64
#  9   tipo        5336 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 417.0+ KB

# %%
# Buscamos las filas con valores NaN
# Corresponden a los totales del reporte
df_fa_hist[ df_fa_hist.isnull().values ]
# Out:
#                   Número    Emisión                 Venc.  \
# 4571  PC 00005-000051210   1/08/2023   1/08/2023 08:36:18
# 4572  PC 00005-000051211   1/08/2023   1/08/2023 08:58:23
# 4573  PC 00005-000051212   1/08/2023   1/08/2023 10:46:53
# 4574  PC 00005-000051212   1/08/2023   1/08/2023 10:46:53
# 4575  PC 00005-000051213   1/08/2023   1/08/2023 12:08:52
# ...                  ...         ...                  ...
# 5331  PC 00005-000051634  22/08/2023  22/08/2023 20:09:34
# 5332  PC 00005-000051635  23/08/2023  23/08/2023 10:12:20
# 5333  PC 00005-000051635  23/08/2023  23/08/2023 10:12:20
# 5334  PC 00005-000051636  23/08/2023  23/08/2023 10:32:42
# 5335  PC 00005-000051636  23/08/2023  23/08/2023 10:32:42
#
#                      Cliente  Monto Base  I.G.V  Otros   Neto  Saldo tipo
# 4571       CLIENTE EVENTUAL        25.42   4.58      0   30.0    NaN   Ve
# 4572       CLIENTE EVENTUAL         2.54   0.46      0    3.0    NaN   Ve
# ...

# %%
# Eliminamos los registros que contienen NaN ya que corresponden a
# líneas de totales de los reportes
df_fa_hist.dropna(inplace=True)
df_fa_hist
# Out:
#                    Número             Emisión                 Venc.  \
# 0     PC: 00001-000015661           19/01/2022           19/01/2022
# 1     PC: 00001-000015646           14/01/2022           14/01/2022
# 2     PC: 00001-000015643           14/01/2022           14/01/2022
# 3     PC: 00001-000015871           14/03/2022           14/03/2022
# 4     PC: 00001-000015838            4/03/2022            4/03/2022
# ...                   ...                  ...                  ...
# 4566   PC 00002-000029286  2023-02-01 00:00:00  2023-02-01 00:00:00
# 4567   PC 00002-000029285  2023-02-01 00:00:00  2023-02-01 00:00:00
# 4568   PC 00002-000029284  2023-02-01 00:00:00  2023-02-01 00:00:00
# 4569   PC 00002-000029283  2023-02-01 00:00:00  2023-02-01 00:00:00
# 4570   PC 00002-000029282  2023-02-01 00:00:00  2023-02-01 00:00:00
#
#                                Cliente  Monto Base   I.G.V  Otros   Neto  \
# 0                    CLIENTE EVENTUAL         8.47   1.525      0   10.0
# ...

# %%
df_fa_hist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4571 entries, 0 to 4570
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Número      4571 non-null   object
#  1   Emisión     4571 non-null   object
#  2   Venc.       4571 non-null   object
#  3   Cliente     4571 non-null   object
#  4   Monto Base  4571 non-null   float64
#  5   I.G.V       4571 non-null   float64
#  6   Otros       4571 non-null   int64
#  7   Neto        4571 non-null   float64
#  8   Saldo       4571 non-null   float64
#  9   tipo        4571 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 392.8+ KB

# %%
df_fa_hist.columns
# Out:
# Index(['Número', 'Emisión ', 'Venc.', 'Cliente', 'Monto Base', 'I.G.V',
#        'Otros', 'Neto', 'Saldo', 'tipo'],
#       dtype='object')

# %%
cols = ['num',
        'fecha_comp',
        'venc',
        'cliente',
        'monto',
        'igv',
        'otros',
        'saldo',
        'neto',
        'tipo']

# %%
df_fa_hist.columns = cols
df_fa_hist = df_fa_hist.loc[:,['num', 'fecha_comp', 'cliente', 'monto', 'tipo']]
df_fa_hist
# Out:
#                       num           fecha_comp  \
# 0     PC: 00001-000015661           19/01/2022
# 1     PC: 00001-000015646           14/01/2022
# 2     PC: 00001-000015643           14/01/2022
# 3     PC: 00001-000015871           14/03/2022
# 4     PC: 00001-000015838            4/03/2022
# ...                   ...                  ...
# 4566   PC 00002-000029286  2023-02-01 00:00:00
# 4567   PC 00002-000029285  2023-02-01 00:00:00
# 4568   PC 00002-000029284  2023-02-01 00:00:00
# 4569   PC 00002-000029283  2023-02-01 00:00:00
# 4570   PC 00002-000029282  2023-02-01 00:00:00
#
#                                cliente   monto tipo
# 0                    CLIENTE EVENTUAL     8.47   Ve
# 1                    CLIENTE EVENTUAL     8.47   Ve
# 2                    CLIENTE EVENTUAL     8.47   Ve
# 3                    CLIENTE EVENTUAL    16.95   Ve
# 4                    CLIENTE EVENTUAL     8.47   Ve
# ...                                ...     ...  ...
# ...

# %%
# Unimos los 2 DF para obtener el histórico completo del los años 2022-2023
df_hist = pd.concat([df_ne_hist, df_fa_hist])
df_hist
# Out:
#                       num           fecha_comp  \
# 0     PC: 00001-000015661           19/01/2022
# 1     PC: 00001-000015646           14/01/2022
# 2     PC: 00001-000015643           14/01/2022
# 3     PC: 00001-000015871           14/03/2022
# 4     PC: 00001-000015838            4/03/2022
# ...                   ...                  ...
# 4566   PC 00002-000029286  2023-02-01 00:00:00
# 4567   PC 00002-000029285  2023-02-01 00:00:00
# 4568   PC 00002-000029284  2023-02-01 00:00:00
# 4569   PC 00002-000029283  2023-02-01 00:00:00
# 4570   PC 00002-000029282  2023-02-01 00:00:00
#
#                                cliente   monto tipo
# 0                    CLIENTE EVENTUAL    10.00   Ve
# 1                    CLIENTE EVENTUAL    10.00   Ve
# 2                    CLIENTE EVENTUAL    10.00   Ve
# 3                    CLIENTE EVENTUAL    20.00   Ve
# 4                    CLIENTE EVENTUAL    10.00   Ve
# ...                                ...     ...  ...
# ...

# %% [markdown]
# Carga y limpieza de Datos de las Ventas a partir de 2022

# %%
FILES_VENTAS = '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Producto_SF_1.xlsx'
FILES_VENTAS
# Out:
# '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Producto_SF_1.xlsx'

# %%
[Path(filename).name for filename in glob.glob(f"{BASE_DIR / FILES_VENTAS}")]
# Out:
# ['Producto_SF_1.xlsx']

# %%
# %%time

df = read_files(FILES_VENTAS, 'tipo', 2)

df.sample(15)
# Out:
# CPU times: user 1.04 s, sys: 3.38 ms, total: 1.04 s
# Wall time: 1.05 s
#                    Número  Reng             Emisión   \
# 225   PC: 00001-000016659   0.0            1/09/2022
# 3892   PC 00002-000029960   0.0  21/02/2023 00:00:00
# 3112   PC 00002-000030740   0.0  2023-10-04 00:00:00
# 4164   PC 00002-000029688   0.0  2023-03-02 00:00:00
# 2687   PC 00002-000031165   0.0  2023-11-05 00:00:00
# 77    PC: 00001-000016309   0.0           27/06/2022
# 4358   PC 00002-000029494   0.0  18/01/2023 00:00:00
# 1945   PC 00002-000031907   0.0  2023-08-07 00:00:00
# 4128   PC 00002-000029724   0.0  2023-06-02 00:00:00
# 2378   PC 00002-000031474   0.0  2023-02-06 00:00:00
# 309   PC: 00001-000016436   0.0           22/07/2022
# 219   PC: 00001-000015757   0.0           14/02/2022
# 747   PC: 00001-000016172   0.0           20/05/2022
# 1126  PC: 00001-000016611   0.0           23/08/2022
# 651   PC: 00001-000015752   0.0           12/02/2022
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5337 entries, 0 to 5336
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Número            5336 non-null   object
#  1   Reng              5336 non-null   float64
#  2   Emisión           5336 non-null   object
#  3   Cliente           5336 non-null   object
#  4   Almacén           1342 non-null   float64
#  5   Cantidad          2108 non-null   float64
#  6   Unid.             5337 non-null   object
#  7   Precio Unitario   1342 non-null   float64
#  8   Monto Base        5336 non-null   float64
#  9   I.V.A.            5336 non-null   float64
#  10  Otros             5336 non-null   float64
#  11  Neto              5336 non-null   float64
#  12  tipo              5337 non-null   object
# dtypes: float64(8), object(5)
# memory usage: 542.2+ KB

# %%
df_aux = df[~df.Número.str.contains('Totales').fillna(False)]
df_aux
# Out:
#                    Número  Reng    Emisión                  Cliente  Almacén  \
# 0     PC: 00001-000015661   0.0  19/01/2022       CLIENTE EVENTUAL       1.0
# 1     PC: 00001-000015646   0.0  14/01/2022       CLIENTE EVENTUAL       1.0
# 2     PC: 00001-000015643   0.0  14/01/2022       CLIENTE EVENTUAL       1.0
# 3     PC: 00001-000015871   0.0  14/03/2022       CLIENTE EVENTUAL       1.0
# 4     PC: 00001-000015838   0.0   4/03/2022       CLIENTE EVENTUAL       1.0
# ...                   ...   ...         ...                     ...      ...
# 5332   PC 00005-000051635   0.0  23/08/2023  EDUARDO ARANA VIZCARRA      NaN
# 5333   PC 00005-000051635   0.0  23/08/2023  EDUARDO ARANA VIZCARRA      NaN
# 5334   PC 00005-000051636   0.0  23/08/2023   RICHARD VIZCARRA MEZA      NaN
# 5335   PC 00005-000051636   0.0  23/08/2023   RICHARD VIZCARRA MEZA      NaN
# 5336                  NaN   NaN         NaN                     NaN      NaN
#
# ...

# %%
# Cambiamos el nombre de las columnas
df_aux.columns
# Out:
# Index(['Número', 'Reng', 'Emisión ', 'Cliente', 'Almacén', 'Cantidad', 'Unid.',
#        'Precio Unitario ', 'Monto Base', 'I.V.A.', 'Otros', 'Neto', 'tipo'],
#       dtype='object')

# %%
cols = ['num', 'reng', 'fecha_comp', 'cliente', 'almacen', 'cantidad',
       'und', 'precio', 'base', 'igv', 'otros', 'neto', 'tipo']
df_aux.columns = cols
df_aux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5337 entries, 0 to 5336
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num         5336 non-null   object
#  1   reng        5336 non-null   float64
#  2   fecha_comp  5336 non-null   object
#  3   cliente     5336 non-null   object
#  4   almacen     1342 non-null   float64
#  5   cantidad    2108 non-null   float64
#  6   und         5337 non-null   object
#  7   precio      1342 non-null   float64
#  8   base        5336 non-null   float64
#  9   igv         5336 non-null   float64
#  10  otros       5336 non-null   float64
#  11  neto        5336 non-null   float64
#  12  tipo        5337 non-null   object
# dtypes: float64(8), object(5)
# memory usage: 583.7+ KB

# %%
df_aux = df_aux.loc[:,['num', 'fecha_comp', 'cliente', 'cantidad', 'neto', 'tipo']]
df_aux.sample(15)
# Out:
#                       num           fecha_comp  \
# 4504   PC 00002-000029348  2023-06-01 00:00:00
# 3273   PC 00002-000030579  30/03/2023 00:00:00
# 413   PC: 00001-000017194           30/12/2022
# 325   PC: 00001-000016093            2/05/2022
# 3342   PC 00002-000030510  25/03/2023 00:00:00
# 3845   PC 00002-000030007  24/02/2023 00:00:00
# 2822   PC 00002-000031030  2023-03-05 00:00:00
# 3460   PC 00002-000030392  18/03/2023 00:00:00
# 4914   PC 00005-000051407            9/08/2023
# 1422   PC 00002-000032430  16/08/2023 00:00:00
# 186   PC: 00001-000017170           24/12/2022
# 1799   PC 00002-000032053  21/07/2023 00:00:00
# 987   PC: 00001-000015756           14/02/2022
# 3016   PC 00002-000030836  17/04/2023 00:00:00
# 813   PC: 00001-000015626           10/01/2022
#
#                                 cliente  cantidad        neto tipo
# 4504            KAREN CANALES BENAVIDES       NaN  500.000000   Pr
# 3273     ERICKA VANESSA GAMARRA CCAYOSI       NaN  130.000000   Pr
# ...

# %% [markdown]
# CONSTRUCCION DEL **DATA** FRAME

# %%
FILES_FA_HIST = '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Producto_Venta.xlsx'
FILES_FA_HIST
# Out:
# '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /Producto_Venta.xlsx'

# %% [markdown]
# Unión del Histórico con las Ventas desde 2022

# %%
df_ventas_totales = pd.concat([df_hist, df_ventas])
df_ventas_totales.sample(20)
# Out:
#                       num           fecha_comp  \
# 4777   PC 00005-000051334            5/08/2023
# 1593   PC 00002-000032259  2023-12-08 00:00:00
# 4118   PC 00002-000029734  2023-07-02 00:00:00
# 4330   PC 00002-000029522  21/01/2023 00:00:00
# 5097   PC 00005-000051504           14/08/2023
# 4147   PC 00002-000029705  2023-04-02 00:00:00
# 2598   PC 00002-000031254          18/05/2023
# 4727   PC 00005-000051303            4/08/2023
# 4389   PC 00002-000029463  14/01/2023 00:00:00
# 3432   PC 00002-000030420  20/03/2023 00:00:00
# 3311   PC 00002-000030541  28/03/2023 00:00:00
# 3732   PC 00002-000030120  2023-02-03 00:00:00
# 258   PC: 00001-000016592           20/08/2022
# 1417   PC 00002-000032435  16/08/2023 00:00:00
# 2003   PC 00002-000031849  2023-03-07 00:00:00
# 1008  PC: 00001-000017071           30/11/2022
# 4140   PC 00002-000029712  2023-04-02 00:00:00
# 3601   PC 00002-000030251  2023-09-03 00:00:00
# 3549   PC 00002-000030303  13/03/2023 00:00:00
# ...

# %%
# Print the column names of the DataFrame
print(df_ventas_totales.columns)
# Out:
# Index(['num', 'fecha_comp', 'cliente', 'monto', 'tipo'], dtype='object')

# %%
df_sin_nan = df.dropna()

# %%
print("\nDataFrame después de eliminar filas con NaN:")
print(df_sin_nan)
# Out:
# DataFrame después de eliminar filas con NaN:
#                    Número  Reng    Emisión                            Cliente  \
# 0     PC: 00001-000015661   0.0  19/01/2022                 CLIENTE EVENTUAL
# 1     PC: 00001-000015646   0.0  14/01/2022                 CLIENTE EVENTUAL
# 2     PC: 00001-000015643   0.0  14/01/2022                 CLIENTE EVENTUAL
# 3     PC: 00001-000015871   0.0  14/03/2022                 CLIENTE EVENTUAL
# 4     PC: 00001-000015838   0.0   4/03/2022                 CLIENTE EVENTUAL
# ...                   ...   ...         ...                               ...
# 1337  PC: 00001-000017067   0.0  28/11/2022       DILAN IMANOL QUISPE ALVAREZ
# 1338  PC: 00001-000017156   0.0  21/12/2022  JORGE ERNESTO ESCALANTE ESCABELA
# 1339  PC: 00001-000016962   0.0   2/11/2022      SULTANA MARIA YAÑEZ CARDENAS
# 1340  PC: 00001-000017078   0.0   1/12/2022                 LIZETH PAYE NUÑEZ
# ...

# %%
df = df.dropna()

# %%
df_ventas_totales.query('num == "PC: 00001-000017201"')
# Out:
#                      num  fecha_comp                     cliente   monto tipo
# 358  PC: 00001-000017201  31/12/2022  EDISON ROBERT SANA CONDORI  120.00   Ve
# 358  PC: 00001-000017201  31/12/2022  EDISON ROBERT SANA CONDORI  101.69   Ve

# %%
df_ventas_totales.sample(10)
# Out:
#                       num           fecha_comp  \
# 4452   PC 00002-000029400  2023-10-01 00:00:00
# 3780   PC 00002-000030072  28/02/2023 00:00:00
# 2868   PC 00002-000030984  27/04/2023 00:00:00
# 4986   PC 00005-000051447           11/08/2023
# 2966   PC 00002-000030886  21/04/2023 00:00:00
# 2799   PC 00002-000031053  2023-04-05 00:00:00
# 1310  PC: 00001-000016883           12/10/2022
# 179   PC: 00001-000017077            1/12/2022
# 4373   PC 00002-000029479  16/01/2023 00:00:00
# 4220   PC 00002-000029632  30/01/2023 00:00:00
#
#                               cliente   monto tipo  cod producto  cantidad
# 4452               MARIA ASUSTA ROSAS   76.27   Ve  NaN      NaN       NaN
# 3780    MARIA ALEJANDRA MEDINA BUTRON  140.00   Ve  NaN      NaN       NaN
# 2868             RICK CCAMA VELASQUEZ  350.00   Pr                     1.0
# 4986                PABLO MAMANI GAMA  150.00   Pr                     1.0
# ...

# %%
# Mostrar las columnas disponibles en el DataFrame
print(df_ventas_totales.columns)
# Out:
# Index(['num', 'fecha_comp', 'cliente', 'monto', 'tipo', 'cod', 'producto',
#        'cantidad'],
#       dtype='object')

# %% [markdown]
# Tasa de cambio
# Para mitigar los efectos de la inflación, los montos, originalmente en Soles , serán transformados a montos en $USD. Para eso, utilizamos un archivo excel **con** todas las tasas de cambio diarias. Luego asignamos la tasa correspondiente a cada registro según la fecha.

# %%
FILE_DOLAR = '/content/drive/MyDrive/DATA OPTICA SAN FRANCISCO /tasa_dolar.csv'
df_dolar = pd.read_csv(f"{BASE_DIR / FILE_DOLAR}", sep=';', encoding='ISO-8859-1')
df_dolar
# Out:
#     fecha,tasa dlar
# 0    29.09.2023,3.78
# 1    28.09.2023,3.77
# 2    27.09.2023,3.79
# 3    26.09.2023,3.77
# 4    25.09.2023,3.76
# ..               ...
# 450  07.01.2022,3.92
# 451  06.01.2022,3.96
# 452  05.01.2022,3.95
# 453  04.01.2022,3.95
# 454  03.01.2022,3.97
#
# [455 rows x 1 columns]
